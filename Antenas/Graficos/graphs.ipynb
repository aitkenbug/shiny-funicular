# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#importacion de CSVs de la data de HFSS

nonchange = pd.read_csv("")
sparametro = pd.read_csv("https://raw.githubusercontent.com/aitkenbug/shiny-funicular/main/Antenas/Graficos/data/Parametro%20S(1%2C1).csv?token=GHSAT0AAAAAABXZQVXRHKN7LXF4DBKIV2O2YYYEJCA")
pattern2D025 = pd.read_csv("https://raw.githubusercontent.com/aitkenbug/shiny-funicular/main/Antenas/Graficos/data/2D%20pattern%201GHz.csv?token=GHSAT0AAAAAABXZQVXROZ7IIROVQG5POTREYYYEJWA")
pattern2D1 = pd.read_csv("https://raw.githubusercontent.com/aitkenbug/shiny-funicular/main/Antenas/Graficos/data/2D%20pattern%201GHz.csv?token=GHSAT0AAAAAABXZQVXQ4GHDAPXATV74PGIKYYYEH3Q")
pattern2D2 = pd.read_csv("https://raw.githubusercontent.com/aitkenbug/shiny-funicular/main/Antenas/Graficos/data/2D%20pattern%202GHz.csv?token=GHSAT0AAAAAABXZQVXQIGP6E6OW34YVVYE2YYYEHPA")
pattern2D3 = pd.read_csv("https://raw.githubusercontent.com/aitkenbug/shiny-funicular/main/Antenas/Graficos/data/2D%20pattern%203GHz.csv?token=GHSAT0AAAAAABXZQVXQGN6XJEISDNIGY6HEYYYEIHQ")

# %%
# Grafico del parametro s(1,1) con las iteraciones para encontrar su peak en 1.3GHz
s = sparametro.loc[:, sparametro.columns != 'Freq [GHz]']
x = sparametro["Freq [GHz]"].to_numpy()
y = s
plt.figure(figsize=(15,10), dpi=120)
plt.plot(x, y)
plt.xticks(np.arange(min(sparametro['Freq [GHz]']),2.1,0.1))
plt.yticks(np.arange(-22,2,2))
plt.title("Iteraciones de largos para el barrido de frecuencia 200MHz-2GHz")
plt.xlabel("")
plt.ylabel("")
plt.legend(['Largo: 148mm',
 'Largo: 146mm',
 'Largo: 144mm',
 'Largo: 142mm',
 'Largo: 140mm',
 'Largo: 138mm',
 'Largo: 136mm',
 'Largo: 134mm',
 'Largo: 132mm',
 'Largo: 130mm',
 'Largo: 128mm',
 'Largo: 126mm',
 'Largo: 124mm',
 'Largo: 122mm',
 'Largo: 120mm',
 'Largo: 118mm',
 'Largo: 116mm',
 'Largo: 114mm',
 'Largo: 112mm',
 'Largo: 110mm',
 'Largo: 108mm',
 'Largo: 106mm',
 'Largo: 105mm',
 'Largo: 104mm',
 'Largo: 103mm',
 'Largo: 102mm',
 'Largo: 100mm'])
plt.grid()
plt.show()

# %%
# Grafico para el sweep del peak en 1.3GHz
s = sparametro.loc[:, sparametro.columns != 'Freq [GHz]']
x1 = sparametro["Freq [GHz]"].to_numpy()
y2 = sparametro["dB(S(1,1)) [] - l='23.5mm'"]
plt.figure(figsize=(15,10), dpi=120)
plt.plot(x1, y2, color="tab:purple")
plt.xticks(np.arange(min(sparametro['Freq [GHz]']),2.1,0.1))
plt.yticks(np.arange(-22,2,2))
plt.title("")
plt.xlabel("")
plt.ylabel("")
plt.legend(['Largo: 103mm'])
plt.grid()
plt.show()

# %%
# Patron 3D dipolo ideal para 0.25GHz
