# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#importacion de CSVs de la data de HFSS

nonchange = pd.read_csv("C:/Users/kabuto/Documents/Github/shiny-funicular/Antenas/Graficos/data/sweepnonchange.csv")
sparametro = pd.read_csv("C:/Users/kabuto/Documents/Github/shiny-funicular/Antenas/Graficos/data/Parametro S(1,1).csv")
pattern2D025 = pd.read_csv("C:/Users/kabuto/Documents/Github/shiny-funicular/Antenas/Graficos/data/2D pattern 0.25GHz.csv")
pattern2D1 = pd.read_csv("C:/Users/kabuto/Documents/Github/shiny-funicular/Antenas/Graficos/data/2D pattern 1GHz.csv")
pattern2D2 = pd.read_csv("C:/Users/kabuto/Documents/Github/shiny-funicular/Antenas/Graficos/data/2D pattern 2GHz.csv")
pattern2D3 = pd.read_csv("C:/Users/kabuto/Documents/Github/shiny-funicular/Antenas/Graficos/data/2D pattern 3GHz.csv")

# %% [markdown]
# # Parte A

# %%
# Funcion para graficar los patrones 2D de radiacion

def two_dim_plot(x, y, angles=None):

  plt.figure(figsize=(10,10))
  ax = plt.subplot(111, polar=True)
  ax.set_theta_zero_location('N')
  ax.set_theta_direction('clockwise')
  plt.plot(x, y)
  ax.set_ylim(-20,0)
  ax.set_yticks(np.array([-30, -20, -10, -3, 0, 3]))
  ax.set_yticklabels(['-30dB', '-20dB', '-10dB', '-3dB', '0dB', '3dB'], fontsize=13)
  plt.title(r"Patrón de radiación normalizado [dB]. Plano $/phi=0^o$", size=20)

  if angles:
    ax.set_xticks(np.array(angles)/180*np.pi)
  plt.xticks(fontsize=13)
  plt.show()

# %%
pattern2D025
# Out:
#      Theta [deg]  dB(GainTotal) [] - Freq='0.25GHz' Phi='0deg'
# 0              0                                    -50.787466
# 1              2                                    -28.260777
# 2              4                                    -21.945214
# 3              6                                    -18.333428
# 4              8                                    -15.797236
# ..           ...                                           ...
# 176          352                                    -15.510607
# 177          354                                    -17.951150
# 178          356                                    -21.371640
# 179          358                                    -27.112733
# 180          360                                    -50.787466
#
# [181 rows x 2 columns]

# %%
def to_rad(deg):
    rad1 = []
    for i in deg:
        rad1.append(i*0.017453)
    return rad1

# %%
ax = plt.subplot(111, polar=True)
ax.plot(to_rad(pattern2D025["Theta [deg]"]), pattern2D025["dB(GainTotal) [] - Freq='0.25GHz' Phi='0deg'"], color='r', linewidth=3)
ax.grid(True)

ax.set_title("Gain at an elevation of 45 degrees", va='bottom')
plt.savefig('RadiationPattern2D025.png')
plt.show()

# %%
two_dim_plot(["Theta [degpattern2D025]"], pattern2D025["dB(GainTotal) [] - Freq='1GHz' Phi='0deg'"])

# %% [markdown]
# # Parte B

# %%
# Resultados del la solucion de campo lejano con las escuaciones de maxwell computarizado

# %% [markdown]
# # Parte C
# Lista

# %%
s = nonchange.loc[:, nonchange.columns != 'Freq [GHz]']
x = nonchange["Freq [GHz]"].to_numpy()
y = s
plt.figure(figsize=(20,10), dpi=120)
plt.rcParams.update({'font.size': 18})
plt.plot(x, y)
plt.xticks(np.arange(min(sparametro['Freq [GHz]']),2.1,0.1))
plt.yticks(np.arange(-22,2,2))
plt.title("Barrido de frecuencia 200MHz-2GHz")
plt.xlabel("Freq [GHz]")
plt.ylabel("dB(S(1,1))")
plt.legend(['150mm'])
plt.grid()
plt.savefig("Barrido de frecuencia 200MHz-2GHz.png")

# %% [markdown]
# # Parte D
# Lista

# %%
# Grafico del parametro s(1,1) con las iteraciones para encontrar su peak en 1.3GHz
s = sparametro.loc[:, sparametro.columns != 'Freq [GHz]']
x1 = sparametro["Freq [GHz]"].to_numpy()
y1 = s
plt.figure(figsize=(20,10), dpi=120)
plt.rcParams.update({'font.size': 18})
plt.plot(x1, y1)
plt.xticks(np.arange(min(sparametro['Freq [GHz]']),2.1,0.1))
plt.yticks(np.arange(-22,2,2))
plt.title("Iteraciones de largos para el barrido de frecuencia 200MHz-2GHz")
plt.xlabel("Freq [GHz]")
plt.ylabel("dB(S(1,1))")
plt.legend(['148mm',
 '146mm',
 '144mm',
 '142mm',
 '140mm',
 '138mm',
 '136mm',
 '134mm',
 '132mm',
 '130mm',
 '128mm',
 '126mm',
 '124mm',
 '122mm',
 '120mm',
 '118mm',
 '116mm',
 '114mm',
 '112mm',
 '110mm',
 '108mm',
 '106mm',
 '105mm',
 '104mm',
 '103mm',
 '102mm',
 '100mm'], fontsize=12)
plt.grid()

plt.savefig("Iteraciones de largos.png")

# %%
# Grafico para el sweep del peak en 1.3GHz
s = sparametro.loc[:, sparametro.columns != 'Freq [GHz]']
x2 = sparametro["Freq [GHz]"].to_numpy()
y2 = sparametro["dB(S(1,1)) [] - l='23.5mm'"]
plt.figure(figsize=(20,10), dpi=120)
plt.plot(x2, y2, color="tab:purple")
plt.xticks(np.arange(min(sparametro['Freq [GHz]']),2.1,0.1))
plt.yticks(np.arange(-22,2,2))
plt.title("Barrido de frecuencia para antena de largo optimizado")
plt.xlabel("Freq [GHz]")
plt.ylabel("dB(S(1,1))")
plt.legend(['Largo: 103mm'])
plt.grid()

plt.savefig("largo optimizado.png")

# %% [markdown]
# # Parte e

# %%
# parte real e imaginaria de la antena
