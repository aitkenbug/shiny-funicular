# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#importacion de CSVs de la data de HFSS

zparametro = pd.read_csv("https://raw.githubusercontent.com/aitkenbug/shiny-funicular/main/Antenas/Graficos/data/parametroz.csv")
nonchange = pd.read_csv("https://raw.githubusercontent.com/aitkenbug/shiny-funicular/main/Antenas/Graficos/data/sweepnonchange.csv")
sparametro = pd.read_csv("https://raw.githubusercontent.com/aitkenbug/shiny-funicular/main/Antenas/Graficos/data/Parametro%20S(1%2C1).csv")
pattern2D025 = pd.read_csv("https://raw.githubusercontent.com/aitkenbug/shiny-funicular/main/Antenas/Graficos/data/2d%20pattern%200GHz.csv")
pattern2D1 = pd.read_csv("https://raw.githubusercontent.com/aitkenbug/shiny-funicular/main/Antenas/Graficos/data/2D%20pattern%201GHz.csv")
pattern2D2 = pd.read_csv("https://raw.githubusercontent.com/aitkenbug/shiny-funicular/main/Antenas/Graficos/data/2D%20pattern%202GHz.csv")
pattern2D3 = pd.read_csv("https://raw.githubusercontent.com/aitkenbug/shiny-funicular/main/Antenas/Graficos/data/2D%20pattern%203GHz.csv")
pattern3D025 = pd.read_csv("https://raw.githubusercontent.com/aitkenbug/shiny-funicular/main/Antenas/Graficos/data/3d%20pattern%200GHz.csv")
pattern3D1 = pd.read_csv("https://raw.githubusercontent.com/aitkenbug/shiny-funicular/main/Antenas/Graficos/data/3D%20pattern%201GHz.csv")
pattern3D2 = pd.read_csv("https://raw.githubusercontent.com/aitkenbug/shiny-funicular/main/Antenas/Graficos/data/3D%20pattern%202GHz.csv")
pattern3D3 = pd.read_csv("https://raw.githubusercontent.com/aitkenbug/shiny-funicular/main/Antenas/Graficos/data/3D%20pattern%203GHz.csv")

# %% [markdown]
# # Parte A

# %%
# Funcion para graficar los patrones 2D de radiacion

def two_dim_plot(x, y, angles=None):

  plt.figure(figsize=(10,10))
  ax = plt.subplot(111, polar=True)
  ax.set_theta_zero_location('N')
  ax.set_theta_direction('clockwise')
  plt.plot(x, y)
  ax.set_ylim(-20,0)
  ax.set_yticks(np.array([-30, -20, -10, -3, 0, 3]))
  ax.set_yticklabels(['-30dB', '-20dB', '-10dB', '-3dB', '0dB', '3dB'], fontsize=13)
  plt.title(r"Patrón de radiación normalizado [dB]. Plano $/phi=0^o$", size=20)

  if angles:
    ax.set_xticks(np.array(angles)/180*np.pi)
  plt.xticks(fontsize=13)
  plt.show()

# %%
def to_rad(deg):
    rad1 = []
    for i in deg:
        rad1.append(i*0.017453)
    return rad1

# %%
pattern2D025.iloc[:, 0]
# Out:
# 0        0
# 1        2
# 2        4
# 3        6
# 4        8
#       ...
# 176    352
# 177    354
# 178    356
# 179    358
# 180    360
# Name: Theta [deg], Length: 181, dtype: int64

# %% [markdown]
# ## Patrones 2D

# %%
# Patron 2D para 0.25GHz

plt.figure(figsize=(10,10))
ax = plt.subplot(111, polar=True)
ax.plot(to_rad(pattern2D025.iloc[:, 0]), pattern2D025.iloc[:, 1], color='r', linewidth=3)
ax.grid(True)
ax.set_theta_zero_location('N')
# ax.set_yticks(np.array([-60,-50,-40,-30,-20,-10,0]))
# ax.set_yticklabels(["-60dB","-50dB","-40dB","-30dB","-20dB","-10dB","0dB"])
ax.set_title("Patron de radiación a 0.25GHz", va='bottom')
plt.savefig('RadiationPattern2D025.png')
plt.show()

# %%
# Patron 2D para 1GHz

plt.figure(figsize=(10,10))
ax = plt.subplot(111, polar=True)
ax.plot(to_rad(pattern2D1.iloc[:, 0]), pattern2D1.iloc[:, 1], color='r', linewidth=3)
ax.grid(True)
ax.set_theta_zero_location('N')
# ax.set_yticks(np.array([-60,-50,-40,-30,-20,-10,0]))
# ax.set_yticklabels(["-60dB","-50dB","-40dB","-30dB","-20dB","-10dB","0dB"])
ax.set_title("Patron de radiación a 1GHz", va='bottom')
plt.savefig('RadiationPattern2D1.png')
plt.show()

# %%
# Patron 2D para 2GHz

plt.figure(figsize=(10,10))
ax = plt.subplot(111, polar=True)
ax.plot(to_rad(pattern2D2.iloc[:, 0]), pattern2D2.iloc[:, 1], color='r', linewidth=3)
ax.grid(True)
ax.set_theta_zero_location('N')
# ax.set_yticks(np.array([-60,-50,-40,-30,-20,-10,0]))
# ax.set_yticklabels(["-60dB","-50dB","-40dB","-30dB","-20dB","-10dB","0dB"])
ax.set_title("Patron de radiación a 2GHz", va='bottom')
plt.savefig('RadiationPattern2D2.png')
plt.show()

# %%
# Patron 2D para 1GHz

plt.figure(figsize=(10,10))
ax = plt.subplot(111, polar=True)
ax.plot(to_rad(pattern2D3.iloc[:, 0]), pattern2D3.iloc[:, 1], color='r', linewidth=3)
ax.grid(True)
ax.set_theta_zero_location('N')
# ax.set_yticks(np.array([-60,-50,-40,-30,-20,-10,0]))
# ax.set_yticklabels(["-60dB","-50dB","-40dB","-30dB","-20dB","-10dB","0dB"])
ax.set_title("Patron de radiación a 3GHz", va='bottom')
plt.savefig('RadiationPattern2D3.png')
plt.show()

# %% [markdown]
# ## Patrones 3D

# %%
pat = pattern3D025["dB(GainTotal)"].to_numpy()
zero = np.zeros(32761)
patt = np.array([pat,zero])
patt
# Out:
# array([[-50.7875, -50.7875, -50.7875, ..., -50.7875, -50.7875, -50.7875],
#        [  0.    ,   0.    ,   0.    , ...,   0.    ,   0.    ,   0.    ]])

# %%
# THETA, PHI = np.meshgrid(X, Y)
# R = pat
# X = R * np.sin(PHI) * np.cos(THETA)
# Y = R * np.sin(PHI) * np.sin(THETA)
# Z = R * np.cos(PHI)
# fig = plt.figure()
# ax = fig.add_subplot(1,1,1, projection='3d')
# plot = ax.plot_surface(
#     X, Y, Z, rstride=1, cstride=1, cmap=plt.get_cmap('jet'),
#     linewidth=0, antialiased=False, alpha=0.5)

# plt.show()

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(projection='3d')

X = to_rad(pattern3D025["Phi[deg]"])
Y = to_rad(pattern3D025["Theta[deg]"])
Z = patt

# Plot the surface.
ax.plot_surface(X, Y, Z)

# Tweak the limits and add latex math labels.
#ax.set_zlim(0, 1)
ax.set_xlabel(r'$\phi_\mathrm{real}$')
ax.set_ylabel(r'$\phi_\mathrm{im}$')
ax.set_zlabel(r'$V(\phi)$')
# Out:
# Text(0.5, 0, '$V(\\phi)$')

# %% [markdown]
# # Parte B

# %%
# Resultados del la solucion de campo lejano con las escuaciones de maxwell computarizado

# %% [markdown]
# # Parte C
# Lista

# %%
s = nonchange.loc[:, nonchange.columns != 'Freq [GHz]']
x = nonchange["Freq [GHz]"].to_numpy()
y = s
plt.figure(figsize=(20,10), dpi=120)
plt.rcParams.update({'font.size': 18})
plt.plot(x, y)
plt.xticks(np.arange(min(sparametro['Freq [GHz]']),2.1,0.1))
plt.yticks(np.arange(-22,2,2))
plt.title("Barrido de frecuencia 200MHz-2GHz")
plt.xlabel("Freq [GHz]")
plt.ylabel("dB(S(1,1))")
plt.legend(['150mm'])
plt.grid()
plt.savefig("Barrido de frecuencia 200MHz-2GHz.png")

# %% [markdown]
# # Parte D
# Lista

# %%
# Grafico del parametro s(1,1) con las iteraciones para encontrar su peak en 1.3GHz
s = sparametro.loc[:, sparametro.columns != 'Freq [GHz]']
x1 = sparametro["Freq [GHz]"].to_numpy()
y1 = s
plt.figure(figsize=(20,10), dpi=120)
plt.rcParams.update({'font.size': 18})
plt.plot(x1, y1)
plt.xticks(np.arange(min(sparametro['Freq [GHz]']),2.1,0.1))
plt.yticks(np.arange(-22,2,2))
plt.title("Iteraciones de largos para el barrido de frecuencia 200MHz-2GHz")
plt.xlabel("Freq [GHz]")
plt.ylabel("dB(S(1,1))")
plt.legend(['148mm',
 '146mm',
 '144mm',
 '142mm',
 '140mm',
 '138mm',
 '136mm',
 '134mm',
 '132mm',
 '130mm',
 '128mm',
 '126mm',
 '124mm',
 '122mm',
 '120mm',
 '118mm',
 '116mm',
 '114mm',
 '112mm',
 '110mm',
 '108mm',
 '106mm',
 '105mm',
 '104mm',
 '103mm',
 '102mm',
 '100mm'], fontsize=12)
plt.grid()

plt.savefig("Iteraciones de largos.png")

# %%
# Grafico para el sweep del peak en 1.3GHz
s = sparametro.loc[:, sparametro.columns != 'Freq [GHz]']
x2 = sparametro["Freq [GHz]"].to_numpy()
y2 = sparametro["dB(S(1,1)) [] - l='23.5mm'"]
plt.figure(figsize=(20,10), dpi=120)
plt.plot(x2, y2, color="tab:purple")
plt.xticks(np.arange(min(sparametro['Freq [GHz]']),2.1,0.1))
plt.yticks(np.arange(-22,2,2))
plt.title("Barrido de frecuencia para antena de largo optimizado")
plt.xlabel("Freq [GHz]")
plt.ylabel("dB(S(1,1))")
plt.legend(['Largo: 103mm'])
plt.grid()

plt.savefig("largo optimizado.png")

# %% [markdown]
# # Parte e

# %%
# parte real e imaginaria de la antena

xz = zparametro.iloc[:, 0]
yr= zparametro.iloc[:, 1]
yi = zparametro.iloc[:, 2]
plt.figure(figsize=(20,10), dpi=120)
plt.rcParams.update({'font.size': 18})
plt.plot(xz, yr)
plt.plot(xz, yi)
plt.title("Impedancia de la antena vs Frecuencia")
plt.xticks(np.arange(min(sparametro['Freq [GHz]']),2.1,0.1))
plt.xlabel("Freq [GHz]")
plt.ylabel("Z(S(1,1))")
plt.legend(["Re[Z]","Im[Z]"])
plt.grid()

plt.savefig("impedancia.png")
